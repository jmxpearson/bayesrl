# %% [markdown]
# # Fit some Bayesian RL models

# %% [markdown]
# ## Ready the data...

# %%
from __future__ import division
import numpy as np
import pandas as pd
import pystan
import matplotlib.pyplot as plt
% matplotlib inline
plt.style.use('ggplot')
plt.rcParams['figure.figsize'] = (10.0, 8.0)

# %% [markdown]
# Let's set up some parameters:

# %%
input_file = 'data/test_data.csv'
model_name = 'model3b'

# %% [markdown]
# And we can run the model:

# %%
# %run runmodel $model_name $input_file
# Out:
# /Users/jmxp/anaconda/lib/python3.5/site-packages/numpy/lib/function_base.py:4033: RuntimeWarning: Invalid value encountered in median for 42 results
#   r = func(a, **kwargs)
# Writing subject 0
# Writing subject 1
# Writing subject 2
# Writing subject 3
# Writing subject 4
# Writing subject 5

# %%
alpha_df = pd.Panel(samples['alpha']).to_frame().transpose()
alpha_df.columns.names = ['Subject', 'Condition']
alpha_df.plot(kind='density', legend=False);
plt.xlim(0, 1);
plt.ylim(0, 30);

# %%
fit.plot('beta');
