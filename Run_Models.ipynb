# %% [markdown]
# # Fit some Bayesian RL models

# %% [markdown]
# ## Ready the data...

# %%
from __future__ import division
import numpy as np
import pandas as pd
import pystan
import matplotlib.pyplot as plt
% matplotlib inline
plt.style.use('ggplot')
plt.rcParams['figure.figsize'] = (10.0, 8.0)

# %% [markdown]
# Let's set up some parameters:

# %%
input_file = 'clean_data.csv'
model_name = 'model3b'

# %% [markdown]
# And we can run the model:

# %%
# %run runmodel $model_name $input_file
# Out:
# Writing subject 0
# Writing subject 1
# Writing subject 2
# Writing subject 3
# Writing subject 4
# Writing subject 5
# Writing subject 6
# Writing subject 7
# Writing subject 8
# Writing subject 9
# Writing subject 10
# Writing subject 11
# Writing subject 12
# Writing subject 13
# Writing subject 14
# Writing subject 15
# Writing subject 16
# Writing subject 17
# Writing subject 18
# Writing subject 19
# Writing subject 20
# Writing subject 21
# Writing subject 22
# Writing subject 23
# Writing subject 24
# Writing subject 25
# Writing subject 26
# Writing subject 27
# Writing subject 28
# /Users/jmxp/anaconda/lib/python2.7/multiprocessing/queues.py:390: UserWarning: Pickling fit objects is an experimental feature!
# The relevant StanModel instance must be pickled along with this fit object.
# When unpickling the StanModel must be unpickled first.
#   return send(obj)
# ...

# %%
alpha_df = pd.Panel(samples['alpha']).to_frame().transpose()
alpha_df.columns.names = ['Subject', 'Condition']
alpha_df.plot(kind='density', legend=False);
plt.xlim(0, 1);
plt.ylim(0, 30);

# %%
fit.plot('beta');

# %%
fit.plot('a');

# %%
fit.plot('b');

# %%
fit.plot('alpha_pred');
